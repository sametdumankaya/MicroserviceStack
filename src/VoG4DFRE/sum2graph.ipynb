# %%
import networkx as nx
import pandas as pd
import os
from matplotlib import pyplot as plt
path=os.getcwd()

# %%
def norm_cost(graph_name):
    cost=pd.read_csv(graph_name+'_VoG_output',header=None,delim_whitespace=True)
    x=cost[1]
    normalized_x=((x-x.min())/(x.max()-x.min()))*100
    cost.insert(2,2,normalized_x)
    return cost

# %%
def sum2graph(graph_name,n):
    
    '''
    Inputs : graph_name : Name of the graph being summarized 'i.e. alertstorm'
             n : If focused on the first # of nodes 
             oG : The original networkx graph ... returned with VoG attributes  
             
    This code creates a L2 VoG graph used to visualize the structures found in L1 
    
    Additionally writes the original L1 graph with VoG cost attributes for top the top 300 structures. 
    '''
    
    # Initialize Graph Foundation
    G=nx.Graph()
    G.add_node('VoG')
    G.add_node('Bipartite')
    G.add_node('Cliques')
    G.add_node('Stars')
    G.add_node('Summary')
    G.add_node('Top50')
    G.add_node('Top100')
    G.add_node('Top200')
    G.add_node('Top300')
    G.add_edge('VoG','Bipartite')
    G.add_edge('VoG','Cliques')
    G.add_edge('VoG','Stars')
    G.add_edge('VoG','Summary')
    G.add_edge('Summary','Top50')
    G.add_edge('Summary','Top100')
    G.add_edge('Summary','Top200')
    G.add_edge('Summary','Top300')
    
    oG = nx.read_graphml(r'C:\Users\Adam Lawrence.DESKTOP-C98S9IM\VoG_Graph_Summarization\DATA\AlertStrom_HNMTopology_WithAlerts.graphml')
    oG_nodes=list(oG.nodes)
    cost= norm_cost('alertstorm')
    l=len(oG.nodes)
    cost_KG=[0]*l
    
    
    # Read in the data
    raw = open(path+'\DATA\\'+graph_name+'_orderedALL.model', "r")
    structure_list = raw.read().split('\n') 
    
    rank50=[4,5,7,11,12,13,15,16,18,19,20,21,22,23,25,26,27,29,30,31,32,34,35,36,37,38,41,42,43,44,46,47,49]
    rank100=[4,5,7,11,12,13,15,16,18,19,20,21,22,23,25,26,27,29,30,31,32,34,35,36,37,38,41,42,43,44,46,47,49,51,54,55,58,60,61,63,64,65,67,68,69,70,71,72,74,76,77,78,81,82,83,85,86,87,88,89,92,93,94,95,96,97,100]
    rank200=[4,5,7,11,12,13,15,16,18,19,20,21,22,23,25,26,27,29,30,31,32,34,35,36,37,38,41,42,43,44,46,47,49,51,54,55,58,60,61,63,64,65,67,68,69,70,71,72,74,76,77,78,81,82,83,85,86,87,88,89,92,93,94,95,96,97,100,101,102,104,105,106,107,108,110,111,112,113,114,115,129,142,143,144,145,146,147,148,149,151,165,166,167,168,169,170,171,172,173,174,175,189,190,191,192,193,194,195,196,197,199,200]
    rank300=[4,5,7,11,12,13,15,16,18,19,20,21,22,23,25,26,27,29,30,31,32,34,35,36,37,38,41,42,43,44,46,47,49,51,54,55,58,60,61,63,64,65,67,68,69,70,71,72,74,76,77,78,81,82,83,85,86,87,88,89,92,93,94,95,96,97,100,101,102,104,105,106,107,108,110,111,112,113,114,115,129,142,143,144,145,146,147,148,149,151,165,166,167,168,169,170,171,172,173,174,175,189,190,191,192,193,194,195,196,197,199,200,201,202,203,204,205,206,207,273,274,275,276,277,278,281,285,287,288,290,291,293,299]
    
    
    for i in range(n):
        
        G.add_node(i)
        
        if i in rank50:
            G.add_edge(i,'Top50')
        if i in rank100:
            G.add_edge(i,'Top100')
        if i in rank200:
            G.add_edge(i,'Top200')
        if i in rank300:
            G.add_edge(i,'Top300')
            cost_id=cost.index[cost[0] == i].tolist()
            cost_id=cost_id[0]
        
        structure = structure_list[i]
        structure = structure.split(',')
        node1 = structure[0]
        node1_str = node1[3:]
        node2_str = structure[1]
        a_list = node1_str.split()
        b_list = node2_str.split()
        a_map_object = map(int, a_list)
        b_map_object = map(int, b_list)
        
        struct_type = node1[:2] # Type of structure of row i 
        node1_int = list(a_map_object) # set1 of nb , hub of st
        node2_int = list(b_map_object) # set2 of nb , spokes of st

        if struct_type=='nb':
            G.add_edge(i,'Bipartite')
            G.add_node('set1_'+str(i))
            G.add_node('set2_'+str(i))
            G.add_edge('set1_'+str(i),i)
            G.add_edge('set2_'+str(i),i)

            for j in range(len(node1_int)):

                str1=str(node1_int[j])
                idx = node1_int[j]
                G.add_node('L1_'+str1)
                G.add_edge('L1_'+str1,'set1_'+str(i))
                
                if i in rank300:
                    cost_KG[idx] = int(cost[2][cost_id])
                
            for j in range(len(node2_int)):

                str2=str(node2_int[j])
                idx = node2_int[j]
                G.add_node('L1_'+str2)
                G.add_edge('L1_'+str2,'set2_'+str(i))
                
                if i in rank300:
                    cost_KG[idx] = int(cost[2][cost_id])   
                
        if struct_type=='st':
            
            G.add_edge(i,'Stars')
            G.add_node('hub_'+str(i))
            G.add_node('spokes_'+str(i))
            G.add_edge('hub_'+str(i),i)
            G.add_edge('spokes_'+str(i),i)

            for j in range(len(node1_int)):

                str1=str(node1_int[j])
                idx = node1_int[j]
                G.add_node('L1_'+str1)
                G.add_edge('L1_'+str1,'hub_'+str(i))
                                         
                if i in rank300:
                    cost_KG[idx] = int(cost[2][cost_id])

            for j in range(len(node2_int)):

                str2=str(node2_int[j])
                idx = node2_int[j]
                G.add_node('L1_'+str2)
                G.add_edge('L1_'+str2,'spokes_'+str(i))
                                         
                if i in rank300:
                    cost_KG[idx] = int(cost[2][cost_id])
        
    
    zipbObj = zip(oG_nodes,cost_KG)
    oG_cost = dict(zipbObj)
    nx.set_node_attributes(oG, oG_cost, 'norm_cost')
    
    nx.write_graphml(G,graph_name+'L2_VoGstructure_graph.graphml')
    nx.write_graphml(oG,graph_name+'L1_VoGattributes_graph.graphml')
    
    return G , cost_KG , oG_nodes

# %%
G,cost_KG,oG_nodes = sum2graph('alertstorm',229)

# %%
zipbObj = zip(oG_nodes,cost_KG)
oG_cost = dict(zipbObj)
oG_cost
# Out:
# {'0010.e0be.f2d5': 0,
#  '0010.e0be.f335': 0,
#  '0025.90bd.6f02': 0,
#  '0026fdf12e34': 0,
#  '0026fdf12fe9': 62,
#  '0026fdf153f0': 0,
#  '0026fdf15531': 19,
#  '0026fdf1561f': 0,
#  '0026fdf15853': 0,
#  '0026fdf1586a': 0,
#  '0026fdf158c6': 31,
#  '0026fdf15944': 40,
#  '0026fdf15947': 40,
#  '0026fdf1596c': 8,
#  '0026fdf15b62': 31,
#  '0026fdf15c27': 0,
#  '0026fdf15c50': 19,
#  '0026fdf15e88': 19,
#  '0026fdf15e98': 8,
#  '0026fdf15ec4': 19,
#  '0026fdf16003': 19,
#  '0026fdf1602f': 8,
#  '0026fdf1612f': 0,
#  '0026fdf16173': 8,
#  '0026fdf161ba': 19,
#  '0026fdf16230': 8,
#  '0026fdf162e6': 0,
#  '0026fdf162e9': 19,
#  '0026fdf1635d': 8,
#  '0026fdf16367': 19,
#  '0026fdf1647e': 0,
#  '0026fdf87468': 62,
#  '0026fdf87477': 31,
#  '0026fdf88b35': 31,
#  '00908f601904': 62,
#  '00908f601906': 62,
#  '00908f60190d': 0,
#  '00908f601910': 62,
#  '00908f601912': 62,
#  '00908f601913': 62,
#  '00908f601918': 62,
#  '00908f60191e': 0,
#  '00908f601921': 0,
#  '00908f601923': 0,
#  '00908f601925': 62,
#  '00908f601927': 62,
#  '00908f60192a': 0,
#  '00908f60192b': 62,
#  '00908f60192e': 17,
#  '00908f601938': 62,
#  '00908f601945': 0,
#  '00908f601949': 0,
#  '00908f60194c': 62,
#  '00908f601956': 0,
#  '00908f601970': 0,
#  '00908f601976': 0,
#  '00908f601979': 62,
#  '00908f601983': 62,
#  '00908f601996': 0,
#  '00908f6019a2': 18,
#  '00908f6019ba': 18,
#  '00908f6019c8': 31,
#  '00908f6019cb': 18,
#  '00908f6019cd': 0,
#  '00908f6019d3': 18,
#  '00908f6019de': 62,
#  '00908f6019f2': 18,
#  '00908f6019f6': 31,
#  '00908f601a09': 31,
#  '00908f601a13': 31,
#  '00908f601a24': 31,
#  '00908f601a2a': 31,
#  '00908f601a3a': 0,
#  '00908f601a5f': 31,
#  '00908f601a9f': 40,
#  '00908f601aad': 0,
#  '00908f601b40': 31,
#  '00908f601b46': 18,
#  '00908f601b5f': 40,
#  '00908f601b6a': 40,
#  '00908f601b82': 40,
#  '00908f601ba2': 40,
#  '00908f601bcc': 31,
#  '00908f601c76': 40,
#  '00908f601cb2': 40,
#  '00908f601ce4': 40,
#  '00908f601d28': 31,
#  '00908f601d40': 40,
#  '00908f601d46': 18,
#  '00908f601d49': 0,
#  '00908f601d5e': 0,
#  '00908f601d6a': 18,
#  '00908f601d6b': 40,
#  '00908f601d75': 40,
#  '00908f601d80': 62,
#  '00908f601dbf': 62,
#  '00908f601dc7': 31,
#  '00908f601dcc': 31,
#  '00908f601dcf': 31,
#  '00908f601de8': 18,
#  '00908f601df4': 40,
#  '00908f601df6': 0,
#  '00908f601dfb': 17,
#  '00908f601e0e': 17,
#  '00908f601e10': 0,
#  '00908f601e13': 17,
#  '00908f601e16': 18,
#  '00908f601e1e': 0,
#  '00908f601e26': 31,
#  '00908f601e29': 0,
#  '00908f601e2a': 31,
#  '00908f601e2c': 31,
#  '00908f601e32': 31,
#  '00908f601e43': 19,
#  '00908f601e49': 62,
#  '00908f601e4a': 62,
#  '00908f601e5d': 18,
#  '00908f601e5f': 40,
#  '00908f601e66': 19,
#  '00908f601e7c': 0,
#  '00908f601e7e': 19,
#  '00908f601e82': 31,
#  '00908f601e8c': 31,
#  '00908f601e9c': 40,
#  '00908f601eac': 31,
#  '00908f601eb8': 31,
#  '00908f601ebc': 0,
#  '00908f601ec9': 31,
#  '00908f601eda': 31,
#  '00908f601ee2': 31,
#  '00908f601ee5': 0,
#  '00908f601eea': 31,
#  '00908f601ef0': 31,
#  '00908f601eff': 62,
#  '00908f601f06': 9,
#  '00908f601f0b': 17,
#  '00908f601f11': 31,
#  '00908f601f47': 0,
#  '00908f601f4f': 62,
#  '00908f601f62': 62,
#  '00908f601f6a': 0,
#  '00908f601f86': 40,
#  '00908f601fb8': 31,
#  '00908f601fd0': 19,
#  '00908f601fd6': 18,
#  '00908f601ff2': 18,
#  '00908f602002': 0,
#  '00908f60201b': 31,
#  '00908f60204d': 0,
#  '00908f60204f': 31,
#  '00908f602052': 0,
#  '00908f602055': 17,
#  '00908f602056': 31,
#  '00908f602058': 31,
#  '00908f602074': 18,
#  '00908f602075': 31,
#  '00908f602079': 31,
#  '00908f60207a': 31,
#  '00908f60207b': 31,
#  '00908f602097': 31,
#  '00908f6020a0': 31,
#  '00908f6020b7': 31,
#  '00908f6020da': 18,
#  '00908f6020db': 0,
#  '00908f6020e2': 0,
#  '00908f6020ea': 0,
#  '00908f6020eb': 40,
#  '00908f6020ec': 0,
#  '00908f6020ed': 0,
#  '00908f6020f1': 40,
#  '00908f6020f2': 40,
#  '00908f6020f3': 19,
#  '00908f602100': 40,
#  '00908f602106': 40,
#  '00908f602108': 40,
#  '00908f60210a': 19,
#  '00908f60210b': 19,
#  '00908f60210d': 19,
#  '00908f60210e': 62,
#  '00908f602110': 40,
#  '00908f602114': 0,
#  '00908f602116': 40,
#  '00908f602118': 40,
#  '00908f60211b': 40,
#  '00908f60211c': 19,
#  '00908f60211e': 0,
#  '00908f602120': 62,
#  '00908f602122': 40,
#  '00908f602124': 62,
#  '00908f602126': 0,
#  '00908f60212a': 19,
#  '00908f60212e': 0,
#  '00908f60212f': 62,
#  '00908f602130': 62,
#  '00908f602131': 62,
#  '00908f602136': 40,
#  '00908f602137': 40,
#  '00908f602139': 62,
#  '00908f602140': 40,
#  '00908f602147': 0,
#  '00908f60214f': 40,
#  '00908f602152': 40,
#  '00908f602157': 40,
#  '00908f602158': 0,
#  '00908f602159': 19,
#  '00908f602161': 19,
#  '00908f602162': 0,
#  '00908f602163': 40,
#  '00908f602164': 40,
#  '00908f602166': 40,
#  '00908f602167': 40,
#  '00908f602168': 0,
#  '00908f602169': 0,
#  '00908f60216b': 19,
#  '00908f60216e': 0,
#  '00908f602172': 40,
#  '00908f602174': 40,
#  '00908f602176': 19,
#  '00908f602178': 40,
#  '00908f602179': 62,
#  '00908f602181': 40,
#  '00908f602185': 31,
#  '00908f602186': 31,
#  '00908f602192': 31,
#  '00908f6021ac': 31,
#  '00908f6021b0': 31,
#  '00908f6021b9': 31,
#  '00908f6021bc': 31,
#  '00908f6021be': 31,
#  '00908f6021bf': 31,
#  '00908f6021c0': 31,
#  '00908f6021c1': 31,
#  '00908f6021c3': 31,
#  '00908f6021cc': 31,
#  '00908f6021cd': 31,
#  '00908f6021cf': 31,
#  '00908f6021d2': 31,
#  '00908f6021d3': 31,
#  '00908f6021e1': 40,
#  '00908f6021e9': 31,
#  '00908f6021ea': 40,
#  '00908f6021eb': 31,
#  '00908f602203': 31,
#  '00908f602204': 31,
#  '00908f60220b': 31,
#  '00908f60220e': 31,
#  '00908f60220f': 31,
#  '00908f602214': 31,
#  '00908f602217': 31,
#  '00908f60221b': 31,
#  '00908f60221c': 31,
#  '00908f60221e': 31,
#  '00908f602227': 31,
#  '00908f60222e': 0,
#  '00908f60225f': 40,
#  '00908f602260': 31,
#  '00908f60226e': 31,
#  '00908f60227a': 31,
#  '00908f602285': 31,
#  '00908f602286': 0,
#  '00908f60228e': 0,
#  '00908f60228f': 0,
#  '00908f602295': 0,
#  '00908f602297': 31,
#  '00908f6022a1': 31,
#  '00908f6022ba': 0,
#  '00908f6022bf': 17,
#  '00908f6022ce': 17,
#  '00908f6022d1': 18,
#  '00908f6022d3': 0,
#  '00908f6022d4': 18,
#  '00908f6022d5': 0,
#  '00908f6022d8': 17,
#  '00908f6022d9': 0,
#  '00908f6022dc': 0,
#  '00908f6022df': 17,
#  '00908f6022e4': 31,
#  '00908f6022e6': 17,
#  '00908f6022e7': 17,
#  '00908f6022e9': 17,
#  '00908f6022ec': 18,
#  '00908f6022f4': 9,
#  '00908f6022f6': 17,
#  '00908f6022f8': 18,
#  '00908f6022fb': 9,
#  '00908f60232c': 17,
#  '00908f60233c': 0,
#  '00908f60234b': 31,
#  '00908f602356': 31,
#  '00908f602357': 31,
#  '00908f60235a': 31,
#  '00908f60235e': 31,
#  '00908f602377': 31,
#  '00908f6023c8': 0,
#  '00908f60240b': 31,
#  '00908f602453': 62,
#  '00908f602487': 40,
#  '00908f60249a': 40,
#  '00908f6024cb': 40,
#  '00908f602517': 31,
#  '00908f602543': 31,
#  '00908f602545': 19,
#  '00908f60256a': 31,
#  '00908f60256d': 18,
#  '00908f602595': 18,
#  '00908f602600': 18,
#  '00908f602601': 9,
#  '00908f602602': 0,
#  '00908f60262b': 9,
#  '00908f602630': 9,
#  '00908f602641': 31,
#  '00908f602649': 62,
#  '00908f60264a': 17,
#  '00908f60265b': 17,
#  '00908f60267e': 17,
#  '00908f60268c': 17,
#  '00908f6026d0': 17,
#  '00908f6026fa': 31,
#  '00de.fb17.70fd': 17,
#  '00de.fb17.715d': 0,
#  '05CF54D2147/00000C': 0,
#  '10.0.79.36': 0,
#  '10.247.1.38': 0,
#  '10.247.1.39': 16,
#  '10.247.1.69': 16,
#  '10.247.32.2': 16,
#  '10.247.32.3': 16,
#  '10.248.252.114': 16,
#  '10.248.252.115': 16,
#  '10.248.252.130': 16,
#  '10.248.252.131': 16,
#  '10.248.252.146': 16,
#  '10.248.252.147': 16,
#  '10.248.252.162': 16,
#  '10.248.252.163': 16,
#  '10.248.252.226': 16,
#  '10.248.252.227': 16,
#  '10.248.252.242': 16,
#  '10.248.252.243': 16,
#  '10.248.252.34': 16,
#  '10.248.252.35': 16,
#  '10.248.252.50': 16,
#  '10.248.252.51': 16,
#  '10.248.252.82': 16,
#  '10.248.252.83': 16,
#  '10.248.252.98': 16,
#  '10.248.252.99': 16,
#  '10.248.254.130': 16,
#  '10.248.254.131': 16,
#  '10.248.254.146': 16,
#  '10.248.254.147': 16,
#  '10.248.254.162': 16,
#  '10.248.254.163': 16,
#  '10.248.254.2': 16,
#  '10.248.254.3': 16,
#  '10.248.254.34': 16,
#  '10.248.254.35': 16,
#  '10.248.254.50': 16,
#  '10.248.254.51': 16,
#  '10.248.254.82': 16,
#  '10.248.254.83': 16,
#  '10.60.105.114': 16,
#  '10.60.105.115': 16,
#  '10.60.14.66': 16,
#  '10.60.14.67': 16,
#  '10.64.180.11': 16,
#  '10.64.180.12': 16,
#  '10.64.186.4': 16,
#  '10.64.186.5': 16,
#  '172.16.30.2': 16,
#  '172.16.30.3': 16,
#  '172.20.25.130': 16,
#  '172.20.25.131': 16,
#  '172.23.101.66': 16,
#  '172.23.101.67': 16,
#  '4550B93133F/00000C': 16,
#  '75981-00003-gw': 0,
#  '789E4956EF5/00000C': 0,
#  'altech-cpt-hm-production-idc-ce': 12,
#  'altech-cpt-hm-production-neocarrier-ce': 0,
#  'AP002c.c865.c594': 0,
#  'AP00FD.22B0.F9B0': 20,
#  'AP00FD.22B1.16F8': 26,
#  'AP00FD.22B1.2B08': 0,
#  'AP00FD.22B5.50E8': 0,
#  'AP4C71.0DDE.C0FE': 0,
#  'AP5C5A.C757.CC7C': 62,
#  'AP5C5A.C7E3.4ACE': 0,
#  'AP5C5A.C7E3.4AD8': 0,
#  'AP700f.6aaf.4188': 0,
#  'AP700f.6aaf.41d0': 0,
#  'AP700f.6aaf.83c0': 0,
#  'AP7C21.0E4C.4A82': 20,
#  'AP885a.92a7.409e': 62,
#  'APa093.5128.5d44': 28,
#  'APa093.5128.5d48': 0,
#  'APa093.5128.5d4c': 0,
#  'APa093.5128.5d5c': 0,
#  'APa093.5128.5d64': 0,
#  'APA093.51D6.9C20': 0,
#  'APA093.51D6.BD40': 9,
#  'APA093.51D6.C7F0': 0,
#  'APa44c.111d.f96d': 0,
#  'APA453.0E06.4690': 28,
#  'APA453.0E06.97E0': 0,
#  'APA453.0E07.24A0': 0,
#  'APf44e.0578.9d10': 0,
#  'AT-TMM-UAT-MARIEVIK-SW1': 0,
#  'ATA001d70607205': 0,
#  'ATA001d70fba627': 24,
#  'ATA001d70fba6eb': 0,
#  'ATA001d70fba706': 0,
#  'ATA001d70fba708': 28,
#  'ATA001d70fba725': 28,
#  'ATA001d70fba839': 28,
#  'ATA001d70fba843': 0,
#  'ATA001d70fbab8c': 28,
#  'ATA0c2724313e22': 13,
#  'ATA34DBFD1877E2': 8,
#  'ATA34DBFD1877F9': 90,
#  'ATA34DBFD1880BF': 90,
#  'ATA34DBFD18DBCB': 0,
#  'ATA34DBFD18DBDE': 90,
#  'ATA34DBFD18DDF2': 0,
#  'ATA34DBFD18E309': 90,
#  'ATA34DBFD18E69E': 90,
#  'ATA34DBFD18FFF9': 0,
#  'ATA54781ae119f3': 9,
#  'ATA6886a7c50231': 0,
#  'ATAb4e9b08d7ff3': 9,
#  'ATAc40acb4d43ac': 73,
#  'ATADCEB941CBB36': 12,
#  'ATADCEB941DCDA5': 73,
#  'ATAece1a985c646': 0,
#  'ATAece1a985c648': 37,
#  'ATAece1a985c6f1': 37,
#  'ATAece1a985cb40': 37,
#  'Atea-Cisco891FW-Plan5-HQ-A501': 11,
#  'atgraao1rtr001': 10,
#  'atgraao1swi001': 100,
#  'atviedc1cgf001': 0,
#  'atviedc1cgr001': 0,
#  'atviedc1lap001': 59,
#  'atviedc1lap002XN': 0,
#  'atviedc1lap003': 0,
#  'atviedc1lap004': 0,
#  'atviedc1lap005': 0,
#  'atviedc1lap006': 0,
#  'atviedc1lap007': 0,
#  'atviedc1lap008': 0,
#  'atviedc1lap009': 0,
#  'atviedc1lap010': 0,
#  'atviedc1lap011': 0,
#  'atviedc1lap012': 0,
#  'atviedc1lap017': 0,
#  'atviedc1lap018': 0,
#  'atviedc1lap019': 0,
#  'atviedc1lap020': 0,
#  'atviedc1lap021': 0,
#  'atviedc1lap022': 0,
#  'atviedc1lap023': 0,
#  'atviedc1lap024': 0,
#  'atviedc1lap025': 0,
#  'atviedc1lap101': 0,
#  'atviedc1lap102': 0,
#  'atviedc1lap103': 0,
#  'atviedc1lap104': 0,
#  'atviedc1lap105': 0,
#  'atviedc1lap106': 0,
#  'atviedc1lap107': 0,
#  'atviedc1lap108': 0,
#  'atviedc1lap109': 0,
#  'atviedc1lap110': 0,
#  'atviedc1lap111': 0,
#  'atviedc1lap112': 0,
#  'atviedc1lap113': 0,
#  'atviedc1lap114': 0,
#  'atviedc1lap115': 0,
#  'atviedc1lap116': 0,
#  'atviedc1lap117': 0,
#  'atviedc1lap201': 0,
#  'atviedc1lap202': 0,
#  'atviedc1lap203': 0,
#  'atviedc1lap204': 0,
#  'atviedc1lap205': 0,
#  'atviedc1lap206': 0,
#  'atviedc1lap207': 0,
#  'atviedc1lap208': 0,
#  'atviedc1lap209': 0,
#  'atviedc1lap210': 0,
#  'atviedc1lap211': 0,
#  'atviedc1lap212': 0,
#  'atviedc1lap213': 0,
#  'atviedc1lap214': 0,
#  'atviedc1lap215': 0,
#  'atviedc1lap216': 0,
#  'atviedc1lap217': 0,
#  'atviedc1lap218': 0,
#  'atviedc1rtr001': 0,
#  'atviedc1rtr002': 69,
#  'atviedc1swi001': 50,
#  'atviedc1swi002': 0,
#  'atviedc1swi003': 0,
#  'atviedc1swi004': 0,
#  'atviedc1swi005': 0,
#  'atviedc1swi006': 0,
#  'atviedc1swi007': 0,
#  'atviedc1swi008': 0,
#  'atviedc1swi009': 0,
#  'atviedc1wlc001': 0,
#  'atviedc1wlc002': 0,
#  'atvieso1cgf001': 0,
#  'atvieso1cgr001': 0,
#  'atvieso1hap001': 59,
#  'atvieso1hap001-old': 0,
#  'atvieso1hap002': 0,
#  'atvieso1hap003': 0,
#  'atvieso1rtr001': 0,
#  'atvieso1swi001': 100,
#  'atvieso1swi002': 0,
#  'atvieso1swi003': 0,
#  'aubneao3rtr001': 0,
#  'aumelao1hap001': 0,
#  'aumelao1rtr001': 0,
#  'aumelao1swi001': 0,
#  'ausydao1hap001': 0,
#  'ausydao1rtr001': 0,
#  'ausydao1swi001': 0,
#  'ausydcc1cgf001': 0,
#  'ausydcc1cgr001': 0,
#  'ausydcc1cgs001': 59,
#  'ausydcc1gpr101': 0,
#  'ausydcc1gpr201': 0,
#  'ausydcc1gps101': 0,
#  'ausydcc1gps151': 59,
#  'ausydcc1gps152': 59,
#  'ausydcc1gps199': 59,
#  'ausydcc1gps201': 0,
#  'ausydcc1gps299': 59,
#  'ausyddc1hap001': 0,
#  'ausyddc1hap002': 0,
#  'ausyddc1hap004': 0,
#  'ausyddc1hap005': 0,
#  'ausyddc1rtr001': 0,
#  'ausyddc1rtr002': 69,
#  'ausyddc1swi001': 50,
#  'ausyddc1swi002': 0,
#  'ausyddc1swi003': 0,
#  'ausydso1cgr001': 0,
#  'ausydso1cgs001': 59,
#  'ausydso1hap001': 0,
#  'ausydso1hap002': 0,
#  'ausydso1hap003': 0,
#  'ausydso1hap004': 0,
#  'ausydso1hap005': 0,
#  'ausydso1rtr001': 0,
#  'ausydso1rtr002': 69,
#  'ausydso1sfe001': 50,
#  'ausydso1swi001': 0,
#  'ausydso1swi002': 0,
#  'ausydso1swi003': 0,
#  'ausydso1wlc003': 0,
#  'ausydso1wlc004': 0,
#  'axis-accc8ef15e68': 0,
#  'b4b5.2f55.47c9': 0,
#  'b4b5.2f55.47cd': 0,
#  'babnxao1hap001': 0,
#  'babnxao1rtr001': 0,
#  'bdchipo1rtr001': 100,
#  'bdchipo1swi001': 0,
#  'BDDH2109': 0,
#  'BDDH2129': 79,
#  'BDDH2244': 67,
#  'BDDH2301': 0,
#  'BDDH2364': 67,
#  'BDDH2721': 79,
#  'BDDH2749': 79,
#  'BDDH2766': 79,
#  'bddhacc1rtr001': 0,
#  'bddhacc1rtr002': 69,
#  'bddhacc1sfe001': 0,
#  'bddhacc1swi001': 0,
#  'bddhacc1swi002': 0,
#  'bddhacc1swi003': 0,
#  'bddhapo1hap101': 0,
#  'bddhapo1hap102': 67,
#  'bddhapo1hap103': 67,
#  'bddhapo1hap104': 67,
#  'bddhapo1hap105': 67,
#  'bddhapo1hap201': 67,
#  'bddhapo1hap203': 67,
#  'bddhapo1hap204': 67,
#  'bddhapo1hap205': 67,
#  'bddhapo1hap301': 67,
#  'bddhapo1hap302': 67,
#  'bddhapo1hap303': 67,
#  'bddhapo1hap401': 67,
#  'bddhapo1hap402': 64,
#  'bddhapo1hap403': 67,
#  'bddhapo1hap404': 64,
#  'bddhapo1hap501': 64,
#  'bddhapo1hap502': 64,
#  'bddhapo1hap503': 64,
#  'bddhapo1hap504': 64,
#  'bddhapo1hap601': 64,
#  'bddhapo1rtr001': 0,
#  'bddhapo1rtr002': 50,
#  'bddhapo1sfe001': 64,
#  'bddhapo1swi001': 0,
#  'bddhapo1swi002': 67,
#  'bddhapo1swi004': 0,
#  'bddhapo1swi005': 0,
#  'bddhapo1swi006': 0,
#  'bddhapo1swi007': 0,
#  'bddhapo1wlc003': 64,
#  'bddhapo1wlc004': 0,
#  'bddhapo2hap1002': 0,
#  'bddhapo2hap1004': 79,
#  'bddhapo2hap1101': 79,
#  'bddhapo2hap1102': 79,
#  'bddhapo2hap1103': 79,
#  'bddhapo2hap1104': 79,
#  'bddhapo2hap1201': 79,
#  'bddhapo2hap1202': 0,
#  'bddhapo2hap1204': 0,
#  'bddhapo2hap1302': 0,
#  'bddhapo2hap1303': 0,
#  'bddhapo2hap1304': 0,
#  'bddhapo2hap1402': 0,
#  'bddhapo2hap501': 0,
#  'bddhapo2hap502': 0,
#  'bddhapo2hap504': 0,
#  'bddhapo2hap601': 0,
#  'bddhapo2hap604': 0,
#  'bddhapo2hap801': 0,
#  'bddhapo2hap802': 0,
#  'bddhapo2hap804': 0,
#  'bddhapo2hap901': 0,
#  'bddhapo2hap902': 79,
#  'bddhapo2hap904': 79,
#  'bddhapo2hap905': 79,
#  'bddhapo2rtr001': 79,
#  'bddhapo2swi001': 79,
#  'bddhapo2swi002': 0,
#  'bddhapo2swi003': 0,
#  'bddhapo2swi004': 79,
#  'bddhapo2swi005': 0,
#  'BE-TMM-UAT-Marievik-SW1': 0,
#  'beantao1hap001': 0,
#  'beantao1hap002': 0,
#  'beantao1hap003': 0,
#  'beantao1rtr001': 0,
#  'beantao1swi001': 100,
#  'bebrucc1cgf001': 0,
#  'bebrucc1cgr001': 0,
#  'bebrucc1cgs001': 59,
#  'bebrucc1rtr001': 0,
#  'bebruso1hap001': 0,
#  'bebruso1hap002': 55,
#  'bebruso1hap003': 55,
#  'bebruso1hap004': 55,
#  'bebruso1rtr001': 55,
#  'bebruso1sfe001': 55,
#  'bebruso1swi001': 55,
#  'bebruso1swi002': 55,
#  'bebruso1swi003': 55,
#  'begheao1hap001': 55,
#  'begheao1rtr001': 0,
#  'begheao1swi001': 100,
#  'beghldc1cgf001': 0,
#  'beghldc1cgr001': 0,
#  'beghldc1cgs001': 59,
#  'beghldc1lap200': 0,
#  'beghldc1lap201_prio1': 0,
#  'beghldc1lap202_prio1': 0,
#  'beghldc1lap203_prio1': 0,
#  'beghldc1lap204_prio1': 0,
#  'beghldc1lap205_prio1': 0,
#  'beghldc1lap206': 0,
#  'beghldc1lap207_prio1': 0,
#  'beghldc1lap208_prio1': 0,
#  'beghldc1lap209_prio1': 0,
#  'beghldc1lap210_prio1': 0,
#  'beghldc1lap211_prio1': 0,
#  'beghldc1lap212_prio1': 0,
#  'beghldc1lap213': 0,
#  'beghldc1lap214_prio1': 0,
#  'beghldc1lap215_prio1': 0,
#  'beghldc1lap216_prio1': 0,
#  'beghldc1lap217_prio1': 0,
#  'beghldc1lap218_prio1': 0,
#  'beghldc1lap219': 0,
#  'beghldc1lap220': 0,
#  'beghldc1lap221': 0,
#  'beghldc1lap222': 0,
#  'beghldc1lap223': 0,
#  'beghldc1lap224': 0,
#  'beghldc1lap225': 0,
#  'beghldc1lap250_prio1': 0,
#  'beghldc1lap251_prio1': 0,
#  'beghldc1lap252_prio1': 0,
#  'beghldc1lap253_prio1': 0,
#  'beghldc1lap254_prio1': 0,
#  'beghldc1lap255_prio1': 0,
#  'beghldc1lap256_prio1': 0,
#  'beghldc1lap257_prio1': 0,
#  'beghldc1lap258_prio1': 0,
#  'beghldc1lap259_prio1': 0,
#  'beghldc1lap260_prio1': 0,
#  'beghldc1lap261_prio1': 0,
#  'beghldc1lap262_prio1': 0,
#  'beghldc1lap263_prio1': 0,
#  'beghldc1lap264_prio1': 0,
#  'beghldc1lap265_prio1': 0,
#  'beghldc1lap266_prio1': 0,
#  'beghldc1lap300': 0,
#  'beghldc1lap301': 0,
#  'beghldc1lap302': 0,
#  'beghldc1lap303': 0,
#  'beghldc1lap304': 0,
#  'beghldc1lap305': 0,
#  'beghldc1lap306': 0,
#  'beghldc1lap307': 0,
#  'beghldc1lap308': 0,
#  'beghldc1lap309': 0,
#  'beghldc1lap311': 0,
#  'beghldc1lap312': 0,
#  'beghldc1lap313': 0,
#  'beghldc1lap314': 0,
#  'beghldc1lap315': 0,
#  'beghldc1lap316': 0,
#  'beghldc1lap317': 0,
#  'beghldc1lap318': 0,
#  'beghldc1lap319': 0,
#  'beghldc1lap320': 0,
#  'beghldc1lap321': 0,
#  'beghldc1lap322': 0,
#  'beghldc1lap350': 0,
#  'beghldc1lap351': 0,
#  'beghldc1lap352': 0,
#  'beghldc1lap353': 0,
#  'beghldc1lap354': 0,
#  'beghldc1lap355': 0,
#  'beghldc1lap356': 0,
#  'beghldc1lap357': 0,
#  'beghldc1lap358': 0,
#  'beghldc1lap359': 0,
#  'beghldc1lap360': 0,
#  'beghldc1lap361': 0,
#  'beghldc1lap362': 0,
#  'beghldc1lap363': 0,
#  'beghldc1lap400': 0,
#  'beghldc1lap401': 0,
#  'beghldc1lap402': 0,
#  'beghldc1lap403': 0,
#  'beghldc1lap404': 0,
#  'beghldc1lap405': 0,
#  'beghldc1lap406': 0,
#  'beghldc1lap407': 0,
#  'beghldc1lap408': 0,
#  'beghldc1lap409': 0,
#  'beghldc1lap410': 0,
#  'beghldc1lap412': 0,
#  'beghldc1lap413': 0,
#  'beghldc1lap450': 0,
#  'beghldc1lap451': 0,
#  'beghldc1lap452': 0,
#  'beghldc1lap453': 0,
#  'beghldc1lap454': 0,
#  'beghldc1lap455': 0,
#  'beghldc1lap456': 0,
#  'beghldc1lap457': 0,
#  'beghldc1lap500': 0,
#  'beghldc1lap501': 0,
#  'beghldc1lap502': 0,
#  'beghldc1lap503': 0,
#  'beghldc1lap504': 0,
#  'beghldc1lap505': 0,
#  'beghldc1lap506': 0,
#  'beghldc1lap507': 0,
#  'beghldc1lap508': 0,
#  'beghldc1lap509': 0,
#  'beghldc1lap510': 0,
#  'beghldc1lap511': 0,
#  'beghldc1lap512': 0,
#  'beghldc1lap513': 0,
#  'beghldc1lap514': 0,
#  'beghldc1lap515': 0,
#  'beghldc1lap516': 0,
#  'beghldc1lap517': 0,
#  'beghldc1lap518': 0,
#  'beghldc1lap519': 0,
#  'beghldc1lap520': 0,
#  'beghldc1lap521': 0,
#  'beghldc1lap522': 0,
#  'beghldc1lap523': 0,
#  'beghldc1lap524': 0,
#  'beghldc1lap525': 0,
#  'beghldc1lap526': 0,
#  'beghldc1lap527': 0,
#  'beghldc1lap528': 0,
#  'beghldc1lap529': 0,
#  'beghldc1lap530': 0,
#  'beghldc1rtr001': 0,
#  'beghldc1rtr002': 69,
#  'beghldc1swi001': 50,
#  'beghldc1swi003': 0,
#  'beghldc1swi004': 0,
#  'beghldc1swi005': 0,
#  'beghldc1swi006': 0,
#  'beghldc1swi007': 0,
#  'beghldc1swi008': 0,
#  'beghldc1swi009': 0,
#  'beghldc1swi010': 0,
#  'beghldc1swi011': 0,
#  'beghldc1swi012': 0,
#  'beghldc1swi013': 0,
#  'beghldc1swi014': 0,
#  'beghldc1swi015': 0,
#  'beghldc1swi016': 0,
#  'beghldc1swi017': 0,
#  'beghldc1swi019': 0,
#  'beghldc1swi020': 0,
#  'beghldc1swi022': 0,
#  'beghldc1swi023': 0,
#  'beghldc1swi026': 0,
#  'beghldc1wlc001': 0,
#  'beghldc1wlc001-Standby': 0,
#  'beghldc2lap001': 0,
#  'beghldc2lap002': 0,
#  'beghldc2lap003': 0,
#  'beghldc2lap004': 0,
#  'beghldc2lap005': 0,
#  'beghldc2lap006': 0,
#  'beghldc2lap007': 0,
#  'beghldc2lap008': 0,
#  'beghldc2lap009': 0,
#  'beghldc2lap010': 0,
#  'beghldc2lap011': 0,
#  'beghldc2lap012': 0,
#  'beghldc2lap013': 0,
#  'beghldc2lap014': 0,
#  'beghldc2lap015': 0,
#  'beghldc2lap016': 0,
#  'beghldc2lap017': 0,
#  'beghldc2lap018': 0,
#  'beghldc2lap019': 0,
#  'beghldc2rtr001': 0,
#  'beghldc2swi001': 59,
#  'beghldc2swi002': 0,
#  'beghldc2swi003': 0,
#  'beghldc2swi004': 0,
#  'beghldc2swi005': 0,
#  'beluxao2hap001': 0,
#  'beluxao2rtr001': 9,
#  'beluxao2swi001': 9,
#  'benamao1hap101': 9,
#  'benamao1rtr001': 9,
#  'benamao1swi001': 9,
#  'BESO18017': 9,
#  'BG-TMM-UAT-Marievik-SW1': 55,
#  'bgsofcc1cgf001': 0,
#  'bgsofcc1cgr001': 0,
#  'bgsofcc1cgs001': 59,
#  'bgsofcc1rtr001': 0,
#  'bgsofcc1swi001': 0,
#  'bgsofdc1lap001': 0,
#  'bgsofdc1lap002': 0,
#  'bgsofdc1lap003': 0,
#  'bgsofdc1lap004': 0,
#  'bgsofdc1lap005': 0,
#  'bgsofdc1lap006': 0,
#  'bgsofdc1lap007': 0,
#  'bgsofdc1lap008': 0,
#  'bgsofdc1lap009': 0,
#  'bgsofdc1lap010': 0,
#  'bgsofdc1lap011': 0,
#  'bgsofdc1lap012': 0,
#  'bgsofdc1lap013': 0,
#  'bgsofdc1lap014': 0,
#  'bgsofdc1lap015': 0,
#  'bgsofdc1lap016': 0,
#  'bgsofdc1lap017': 0,
#  'bgsofdc1lap018': 0,
#  'bgsofdc1lap019': 0,
#  'bgsofdc1lap020': 0,
#  'bgsofdc1lap021': 0,
#  'bgsofdc1lap022': 0,
#  'bgsofdc1lap023': 0,
#  'bgsofdc1lap025': 0,
#  'bgsofdc1lap026': 0,
#  'bgsofdc1rtr001': 0,
#  'bgsofdc1rtr002': 69,
#  'bgsofdc1swi001': 50,
#  'bgsofdc1swi002': 0,
#  'bgsofdc1swi003': 0,
#  'bgsofdc1swi004': 0,
#  'bgsofdc1wlc001': 0,
#  'bgsofdc1wlc002': 0,
#  'bgsofsh1hap001': 0,
#  'bgsofsh1hap002': 0,
#  'bgsofsh1rtr001': 0,
#  'bgsofsh1swi001': 100,
#  'bgsofso1cgf001': 0,
#  'bgsofso1cgr001': 0,
#  'bgsofso1cgs001': 59,
#  'BOCFL-HM000-DIA-02.Granitenet.com': 0,
#  'cabradc1hap002': 0,
#  'cabradc1hap003': 19,
#  'cabradc1hap004': 19,
#  'cabradc1rtr001': 19,
#  'cabradc1rtr002': 19,
#  'cabradc1swi001': 19,
#  'cabradc1swi002': 19,
#  'cabradc1swi003': 8,
#  'cabradc1swi004': 8,
#  'cabradc1swi005': 8,
#  'cabradc1swi006': 8,
#  'CAHO460': 8,
#  'camiscc1cgf001': 8,
#  'camiscc1cgr001': 0,
#  'camiscc1cgs001': 59,
#  'camiscc1rtr001': 0,
#  'camiscc1swi002': 0,
#  'camiscc1swi003': 0,
#  'catorao1hap001': 0,
#  'catorao1ipt001': 11,
#  'catorao1rtr001': 11,
#  'catorao1swi001': 11,
#  'catordc1ipt001': 11,
#  'catorso1cgf001': 19,
#  'catorso1cgr001': 0,
#  'catorso1hap1801': 59,
#  'catorso1hap1803': 0,
#  'catorso1hap1804': 0,
#  'catorso1hap1805': 0,
#  'catorso1ipt001': 0,
#  'catorso1rtr001': 0,
#  'catorso1rtr002': 69,
#  'catorso1swi001': 50,
#  'cavanao1hap002': 0,
#  'cavanao1ipt001': 0,
#  'cavanao1rtr001': 0,
#  'cavanao1swi001': 0,
#  'CBS2converter': 0,
#  'CC1-CE-C1941-1': 0,
#  'CD130587_H&M.cgrc.pe': 0,
#  'CDMXDF-1-1D3U87F-001': 32,
#  'CH-TMM-UAT-Marievik-SW1': 32,
#  'chberao2hap401': 0,
#  'chberao2hap402': 0,
#  'chberao2hap403': 0,
#  'chberao2rtr001': 0,
#  'chberao2swi001': 100,
#  'chlauao1rtr001': 0,
#  'chlauao1swi001': 100,
#  'chneudc1cgf001': 0,
#  'chneudc1cgr001': 0,
#  'chneudc1cgs001': 59,
#  'chneudc1lap001_prio1': 0,
#  'chneudc1lap002_prio1': 10,
#  'chneudc1lap003_prio1': 10,
#  'chneudc1lap004_prio1': 10,
#  'chneudc1lap005_prio1': 10,
#  'chneudc1lap006_prio1': 10,
#  'chneudc1lap007_prio1': 10,
#  'chneudc1lap008_prio1': 10,
#  'chneudc1lap009_prio1': 10,
#  'chneudc1lap010_prio1': 0,
#  'chneudc1lap011_prio1': 0,
#  'chneudc1lap012_prio1': 0,
#  'chneudc1lap013_prio1': 0,
#  'chneudc1lap014_prio1': 0,
#  'chneudc1lap015': 11,
#  'chneudc1lap016': 10,
#  'chneudc1lap017': 11,
#  'chneudc1lap018': 10,
#  'chneudc1lap019': 11,
#  'chneudc1lap020': 8,
#  'chneudc1lap021': 8,
#  'chneudc1lap022': 8,
#  'chneudc1lap023': 8,
#  'chneudc1lap024': 11,
#  'chneudc1lap025': 11,
#  'chneudc1lap026': 11,
#  'chneudc1lap027': 8,
#  'chneudc1lap028': 8,
#  'chneudc1lap029': 8,
#  'chneudc1lap030_prio1': 8,
#  'chneudc1lap031': 10,
#  'chneudc1lap032': 10,
#  'chneudc1lap033': 10,
#  'chneudc1lap034': 10,
#  'chneudc1lap035': 11,
#  'chneudc1lap036': 11,
#  'chneudc1lap037': 0,
#  'chneudc1lap038': 11,
#  'chneudc1lap039': 11,
#  'chneudc1lap040': 11,
#  'chneudc1lap041': 11,
#  ...}

# %%
nx.set_node_attributes(oG, oG_cost, 'norm_cost')

# %%
oG.nodes(data=True)
# Out:
# NodeDataView({'0010.e0be.f2d5': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'unknown', 'management_address': 'unknown', 'source': 'lldp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0}, '0010.e0be.f335': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'unknown', 'management_address': 'unknown', 'source': 'lldp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0}, '0025.90bd.6f02': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'unknown', 'management_address': 'unknown', 'source': 'lldp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0}, '0026fdf12e34': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.33.57', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0}, '0026fdf12fe9': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.48.202', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0.6254809115122817}, '0026fdf153f0': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.24.251', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0}, '0026fdf15531': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.65.231', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0.19147676827463747}, '0026fdf1561f': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.9.60', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0}, '0026fdf15853': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.65.40', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0}, '0026fdf1586a': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.41.165', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0}, '0026fdf158c6': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.25.178', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0.31407221071322877}, '0026fdf15944': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.24.92', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0.4014501331754957}, '0026fdf15947': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.17.44', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0.4014501331754957}, '0026fdf1596c': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.41.160', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0.08412252145605209}, '0026fdf15b62': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.9.158', 'source': 'cdp', 'command_files': 0, 'issue_count': 0, 'problem_count': 0, 'topic_count': 0, 'norm_cost': 0.31407221071322877}, '0026fdf15c27': {'vendor': 'unknown', 'os': 'unknown', 'os_version': 'unknown', 'model': 'SIP100', 'management_address': '172.27.24.108', 'source': 'cdp', ' ...

# %%
nx.write_graphml(oG,'L1_test.graphml')

# %%
graph_name='alertstorm'
oG = nx.read_graphml(r'C:\Users\Adam Lawrence.DESKTOP-C98S9IM\VoG_Graph_Summarization\DATA\AlertStrom_HNMTopology_WithAlerts.graphml')
oG_edges=list(oG.edges)
cost= norm_cost('alertstorm')
l=len(oG.nodes)
cost_KG=[None]*l
raw = open(path+'\DATA\\'+graph_name+'_orderedALL.model', "r")
structure_list = raw.read().split('\n')
rank300=[4,5,7,11,12,13,15,16,18,19,20,21,22,23,25,26,27,29,30,31,32,34,35,36,37,38,41,42,43,44,46,47,49,51,54,55,58,60,61,63,64,65,67,68,69,70,71,72,74,76,77,78,81,82,83,85,86,87,88,89,92,93,94,95,96,97,100,101,102,104,105,106,107,108,110,111,112,113,114,115,129,142,143,144,145,146,147,148,149,151,165,166,167,168,169,170,171,172,173,174,175,189,190,191,192,193,194,195,196,197,199,200,201,202,203,204,205,206,207,273,274,275,276,277,278,281,285,287,288,290,291,293,299]
cost
# Out:
#        0       1         2
# 0      4  179416  1.000000
# 1      5  178065  0.900044
# 2      7  177395  0.850474
# 3     11  177008  0.821841
# 4     12  176670  0.796833
# ..   ...     ...       ...
# 133  320  166268  0.027227
# 134  322  166134  0.017313
# 135  324  166023  0.009100
# 136  325  165975  0.005549
# 137  329  165900  0.000000
#
# [138 rows x 3 columns]

# %%
i=142
cost_id=cost.index[cost[0] == i].tolist()
cost_id = cost_id[0]
cost_id
# Out:
# 81

# %%
def cost_KG(i,j,cost_KG):
    
    cost_KG[j] = cost[2][i]
    
    return cost_KG
